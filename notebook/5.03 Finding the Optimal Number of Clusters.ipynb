# %%
import pandas as pd
from sklearn.cluster import KMeans
import altair as alt

# %%
file_url = r'https://raw.githubusercontent.com/sedeba19/Chapter-5/main/data/DataSet_taxstats2015.csv'

# %%
df = pd.read_csv(file_url)

# %%
X = df[['Average total business income', 'Average total business expenses']]

# %%
clusters = pd.DataFrame()
inertia = []
clusters['cluster_range'] = range(1, 15)

for k in clusters['cluster_range']:
    kmeans = KMeans(n_clusters=k).fit(X)
    inertia.append(kmeans.inertia_)
# Out:
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(

# %%
clusters['inertia'] = inertia
clusters
# Out:
#     cluster_range       inertia
# 0               1  1.333516e+13
# 1               2  7.063097e+12
# 2               3  3.718740e+12
# 3               4  2.341877e+12
# 4               5  1.714832e+12
# 5               6  1.224520e+12
# 6               7  9.422735e+11
# 7               8  7.488343e+11
# 8               9  6.348821e+11
# 9              10  5.638087e+11
# 10             11  5.104580e+11
# 11             12  4.596647e+11
# 12             13  4.196314e+11
# 13             14  3.961219e+11

# %%
alt.Chart(clusters).mark_line().encode(alt.X('cluster_range'), alt.Y('inertia'))
# Out:
# alt.Chart(...)

# %%
# look at the Elbow plot, identify the optimal number of clusters
optim_cluster = 4

# %%
kmeans = KMeans(random_state=42, 
                n_clusters=optim_cluster)
kmeans.fit(X)
# Out:
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# f:\USDSI Python Code\The-Data-Science-Workshop-master\env\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=10.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
df['cluster2'] = kmeans.predict(X)
df['cluster2']
# Out:
# 0       1
# 1       0
# 2       2
# 3       0
# 4       1
#        ..
# 2468    0
# 2469    0
# 2470    0
# 2471    0
# 2472    3
# Name: cluster2, Length: 2473, dtype: int32

# %%
df
# Out:
#       Postcode  Count taxable income or loss  Average taxable income or loss  \
# 0         2000                         36185                           47723
# 1         2006                            83                           80905
# 2         2007                          4769                           46549
# 3         2008                          5607                          108816
# 4         2009                          9726                           82938
# ...        ...                           ...                             ...
# 2468       870                         13409                           57704
# 2469       872                          3520                           39965
# 2470       880                           633                           56522
# 2471       885                           600                           86713
# 2472       886                           808                           63557
#
#       Median taxable income or loss  Count salary and wages  \
# 0                             18213                   31293
# 1                             58150                      74
# 2                             31474                    4153
# 3                             41151                    5008
# 4                             50604                    8167
# ...                             ...                     ...
# 2468                          50609                   12299
# 2469                          31883                    3389
# 2470                          42004                     586
# 2471                          68314                     563
# 2472                          53781                     772
#
#       Average salary and wages  Median salary and wages  Count net rent  \
# 0                        38710                    17992            3614
# 1                        82733                    67658              21
# 2                        47386                    34366             548
# 3                        53418                    42892             612
# 4                        74068                    55243            1714
# ...                        ...                      ...             ...
# 2468                     57827                    52378            2515
# 2469                     36355                    29379             301
# 2470                     57525                    43230             179
# 2471                     88820                    75159             239
# 2472                     65861                    56291             192
#
#       Average net rent  Median net rent  ...  Count  total business expenses  \
# 0                  558              207  ...                            1331
# 1                 1042             -807  ...                               4
# 2                -1242             -794  ...                             334
# 3                 1818            -1728  ...                             481
# 4                -2412            -1520  ...                             666
# ...                ...              ...  ...                             ...
# 2468             -3284            -2657  ...                             872
# 2469             -4788            -2593  ...                              66
# 2470             -4964            -3732  ...                              39
# 2471             -8280            -5498  ...                              25
# 2472             -5081            -3146  ...                              26
#
#       Average total business expenses  Median total business expenses  \
# 0                              222191                           20773
# 1                               48971                           18508
# 2                              639499                            9233
# 3                               32173                            9385
# 4                              222993                           11982
# ...                               ...                             ...
# 2468                            44687                           11366
# 2469                            45670                            8498
# 2470                            28700                            6047
# 2471                            39850                            7807
# 2472                            90120                           18718
#
#       Count net tax  Average net tax  Median net tax  \
# 0             17264            27555            5917
# 1                67            28142           19359
# 2              3071            15649            9115
# 3              4061            53976           10583
# 4              7358            32430           14835
# ...             ...              ...             ...
# 2468          11050            14788           10804
# 2469           2314             9017            4614
# 2470            460            16574           10758
# 2471            491            28795           21326
# 2472            634            18141           14250
#
#       Count super total accounts balance  \
# 0                                  51394
# 1                                    137
# 2                                   6711
# 3                                   7676
# 4                                  12718
# ...                                  ...
# 2468                               12755
# 2469                                3328
# 2470                                 588
# 2471                                 586
# 2472                                 774
#
#       Average super total accounts balance  \
# 0                                    68531
# 1                                    90315
# 2                                    41670
# 3                                    54245
# 4                                   126486
# ...                                    ...
# 2468                                 97068
# 2469                                 40555
# 2470                                 90488
# 2471                                127863
# 2472                                 91023
#
#       Median super total accounts balance  cluster2
# 0                                    1110         1
# 1                                   15544         0
# 2                                    5225         2
# 3                                   10373         0
# 4                                   20494         1
# ...                                   ...       ...
# 2468                                39639         0
# 2469                                12492         0
# 2470                                32574         0
# 2471                                71318         0
# 2472                                50926         3
#
# [2473 rows x 29 columns]

# %%
# Plot a scatter plot of the data with the cluster labels
alt.Chart(df).mark_circle().encode(x='Average total business income', 
               y='Average total business expenses', 
               color='cluster2:N', 
               tooltip=['Postcode', 'cluster2', 
                        'Average total business income',
                        'Average total business expenses']).interactive()
# Out:
# alt.Chart(...)
